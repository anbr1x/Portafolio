# %%
import pandas as pd

# Leer una hoja específica del archivo Excel
Hosp_sheet = pd.read_excel('Datos.xls', sheet_name='Hospitales')

# %%
Hosp_sheet
# Out:
#                              Nombre Servicio de Salud
# 0   Metropolitano Norte                           ...  \
# 1   Metropolitano Occidente                       ...
# 2   Metropolitano Occidente                       ...
# 3   Metropolitano Occidente                       ...
# 4   Metropolitano Occidente                       ...
# 5   Metropolitano Central                         ...
# 6   Metropolitano Central                         ...
# 7   Metropolitano Central                         ...
# 8   Metropolitano Oriente                         ...
# 9   Metropolitano Oriente                         ...
# 10  Metropolitano Oriente                         ...
# 11  Metropolitano Oriente                         ...
# 12  Metropolitano Sur                             ...
# 13  Metropolitano Sur                             ...
# 14  Metropolitano Sur                             ...
# 15  Metropolitano Sur                             ...
# ...

# %% [markdown]
# ### CAMAS XSS

# %%
df3 = Hosp_sheet[["Nombre Establecimiento", "Total Camas Críticas"]].groupby("Nombre Establecimiento").max()
df3_ordenado = df3["Total Camas Críticas"].sort_values()
df3_ordenado
# Out:
# Nombre Establecimiento
# Hospital Dr. Félix Bulnes Cerda                                         9
# Hospital Parroquial de San Bernardo                                    16
# Hospital Padre Alberto Hurtado (San Ramón)                             16
# Hospital Adalberto Steeger (Talagante)                                 17
# Hospital el Carmen                                                     18
# Instituto Traumatológico Dr. Teodoro Gebauer                           18
# Hospital de Enfermedades Infecciosas Dr. Lucio Córdova                 20
# Instituto de Neurocirugía Dr. Alfonso Asenjo                           23
# Hospital Clínico de la Florida                                         24
# Hospital Dr. Luis Tisné B.                                             24
# Hospital Dr. Exequiel González Cortés                                  31
# Hospital El Pino                                                       32
# ...

# %%
# !pip install openpyxl
# Out:
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 250.0/250.0 kB 1.7 MB/s eta 0:00:00
# ...

# %%
df3_ordenado.to_excel("MaxCamasCC x SS.xlsx")

# %%
Hosp_sheet["Costo total de instalar el máximo de camas críticas posibles"] = Hosp_sheet["Costo de instalar una cama [MM$]"] * Hosp_sheet["Máxima cantidad de camas a aumetar"]
Hosp_sheet["Costo total de instalar el máximo de camas críticas posibles"].sum()
# Out:
# 240509

# %%
Hosp_sheet[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").max()
# Out:
#                                                     Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Central                                                 44
# Metropolitano Norte                                                   44
# Metropolitano Occidente                                               76
# Metropolitano Oriente                                                 46
# Metropolitano Sur                                                     74
# Metropolitano Sur Oriente                                             55

# %%
Hosp_sheet["Costo de operación anual de una cama [MM$]"].sort_values()
# Out:
# 10    36.6
# 3     39.2
# 17    40.6
# 12    42.9
# 20    43.2
# 6     44.5
# 8     45.4
# 19    46.3
# 16    47.0
# 0     47.2
# 7     49.7
# 14    51.9
# 4     55.5
# 9     56.2
# 18    60.0
# 13    61.6
# 1     62.1
# 11    63.0
# 5     63.1
# 2     65.9
# 15    66.1
# Name: Costo de operación anual de una cama [MM$], dtype: float64

# %% [markdown]
# # Costo promedio diario

# %%
Hosp_sheet["Costo diario GRD4 [MM$]"].mean()
# Out:
# 0.4484761904761904

# %%
df1 = Hosp_sheet.iloc[:,-10:]
df1.mean()
# Out:
# Costo diario GRD1 [MM$]     0.493857
# Costo diario GRD2 [MM$]     0.455857
# Costo diario GRD3 [MM$]     0.470857
# Costo diario GRD4 [MM$]     0.448476
# Costo diario GRD5 [MM$]     0.492190
# Costo diario GRD6 [MM$]     0.420381
# Costo diario GRD7 [MM$]     0.440190
# Costo diario GRD8 [MM$]     0.454524
# Costo diario GRD9 [MM$]     0.458143
# Costo diario GRD10 [MM$]    0.422381
# dtype: float64

# %%
Hosp_sheet[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").mean()
# Out:
#                                                     Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Central                                              35.00
# Metropolitano Norte                                                44.00
# Metropolitano Occidente                                            30.00
# Metropolitano Oriente                                              34.25
# Metropolitano Sur                                                  34.60
# Metropolitano Sur Oriente                                          31.75

# %%
costo_camas = Hosp_sheet[["Nombre Servicio de Salud", "Costo de instalar una cama [MM$]"]].groupby("Nombre Servicio de Salud").min()

costo_camas["Costo 3 camas nuevas"] = costo_camas["Costo de instalar una cama [MM$]"]*3
costo_camas
# Out:
#                                                     Costo de instalar una cama [MM$]
# Nombre Servicio de Salud
# Metropolitano Central                                                           1256  \
# Metropolitano Norte                                                             1407
# Metropolitano Occidente                                                         1066
# Metropolitano Oriente                                                           1056
# Metropolitano Sur                                                               1051
# Metropolitano Sur Oriente                                                       1028
#
#                                                     Costo 3 camas nuevas
# Nombre Servicio de Salud
# Metropolitano Central                                               3768
# Metropolitano Norte                                                 4221
# Metropolitano Occidente                                             3198
# ...

# %% [markdown]
# ## INFO SHEET

# %%
Info_sheet = pd.read_excel('Datos.xls', sheet_name='Información Histórica')
Info_sheet
# Out:
#        Número de llegada                              Hospital al que llega
# 0                      1       Instituto Traumatológico Dr. Teodoro Gebauer  \
# 1                      2                Hospital Clínico San Borja-Arriarán
# 2                      3                         Hospital Dr. Luis Tisné B.
# 3                      4              Hospital Dr. Exequiel González Cortés
# 4                      5                       Hospital Barros Luco Trudeau
# ...                  ...                                                ...
# 65529              65530                Hospital Clínico San Borja-Arriarán
# 65530              65531              Hospital Dr. Exequiel González Cortés
# 65531              65532                              Hospital Del Salvador
# 65532              65533  Hospital de Enfermedades Infecciosas Dr. Lucio...
# 65533              65534  Hospital de Urgencia Asistencia Pública Dr. Al...
#
#          GRD  Día de llegada  Día de salida  Estadia
# ...

# %% [markdown]
# ### Tabla y grafico de frecuencias

# %%
Info_sheet["Numero de pacientes"] = Info_sheet["Día de llegada"]
forgrafic = Info_sheet[["Numero de pacientes", "Día de llegada"]].groupby("Día de llegada").count()

# %%
forgrafic.plot(kind="hist",
              alpha=0.7,
              bins=30,
              title="Frecuencia Pacientes",
              rot=45,
              grid=True,
              )
# Out:
# <Axes: title={'center': 'Frecuencia Pacientes'}, ylabel='Frequency'>

# %%
tabla_frecuencias = pd.DataFrame({'Valor': frecuencias.index, 'Frecuencia': frecuencias.values})
print(tabla_frecuencias)
# Out:
#      Valor  Frecuencia
# 0      420         183
# 1      403         182
# 2      216         175
# 3      262         174
# 4      223         174
# ..     ...         ...
# 419    116         136
# 420    134         136
# 421     58         132
# 422     50         130
# 423    424          82
#
# [424 rows x 2 columns]

# %%
Info_sheet[["GRD", "Estadia"]].groupby("GRD").mean()
# Out:
#        Estadia
# GRD
# GRD1      10.0
# GRD10     10.0
# GRD2       4.0
# GRD3       3.0
# GRD4       6.0
# GRD5       4.0
# GRD6       5.0
# GRD7       4.0
# GRD8       4.0
# GRD9       5.0

# %%
# Contar filas que cumplen el criterio
count = df[(df['Día de llegada'] >= 415) & (df['Día de llegada'] <= 424)].shape[0]

# Imprimir el resultado
print("Número de filas que cumplen el criterio:", count)
# Out:
# Número de filas que cumplen el criterio: 1545

# %%
Info_sheet.loc[Info_sheet["Día de llegada"] >= 415].groupby("GRD").sum()
# Out:
#        Número de llegada                              Hospital al que llega
# GRD
# GRD1             9793283  Hospital Dr. Luis Tisné B.Hospital Dr. Luis Ti...  \
# GRD10           10694028  Hospital Parroquial de San Bernardo      Compl...
# GRD2            10030116  Complejo Hospitalario Dr. Sótero del Río  Hosp...
# GRD3            10806425  Complejo Hospitalario San JoséHospital Clínico...
# GRD4             8939015  Hospital el CarmenHospital Del SalvadorHospita...
# GRD5             9269245  Hospital Parroquial de San Bernardo      Insti...
# GRD6            10422674  Hospital de Urgencia Asistencia Pública Dr. Al...
# GRD7            11330660  Hospital de Enfermedades Infecciosas Dr. Lucio...
# GRD8             9645592  Hospital de Urgencia Asistencia Pública Dr. Al...
# GRD9             9126252  Hospital Dr. Exequiel González CortésComplejo ...
#
#        Día de llegada  Día de salida  Estadia
# GRD
# GRD1            63401          64911     1510
# ...

# %%
Info_sheet[Info_sheet["Día de llegada"] >= 415].groupby("GRD").sum()
# Out:
#        Número de llegada                              Hospital al que llega
# GRD
# GRD1             9793283  Hospital Dr. Luis Tisné B.Hospital Dr. Luis Ti...  \
# GRD10           10694028  Hospital Parroquial de San Bernardo      Compl...
# GRD2            10030116  Complejo Hospitalario Dr. Sótero del Río  Hosp...
# GRD3            10806425  Complejo Hospitalario San JoséHospital Clínico...
# GRD4             8939015  Hospital el CarmenHospital Del SalvadorHospita...
# GRD5             9269245  Hospital Parroquial de San Bernardo      Insti...
# GRD6            10422674  Hospital de Urgencia Asistencia Pública Dr. Al...
# GRD7            11330660  Hospital de Enfermedades Infecciosas Dr. Lucio...
# GRD8             9645592  Hospital de Urgencia Asistencia Pública Dr. Al...
# GRD9             9126252  Hospital Dr. Exequiel González CortésComplejo ...
#
#        Día de llegada  Día de salida  Estadia
# GRD
# GRD1            63401          64911     1510
# ...

# %%
# Encuentra el número que más se repite y cuántas veces se repite
valor_mas_comun = Info_sheet['Día de llegada'].value_counts().idxmax()
repeticiones = Info_sheet['Día de llegada'].value_counts().max()

# Imprime el resultado
print("El número que más se repite es:", valor_mas_comun)
print("Se repite", repeticiones, "veces.")
# Out:
# El número que más se repite es: 420
# Se repite 183 veces.

# %% [markdown]
# # Resolucion Clinica

# %%
RC = pd.read_excel('Datos.xls', sheet_name='GRD')
RC
# Out:
#   ID GRD      Nombre GRD  Costo resolución en Clínica Privada [MM$]
# 0   GRD1       Coronario                                      7.917
# 1   GRD2        Hepático                                      3.417
# 2   GRD3    Respiratorio                                      2.915
# 3   GRD4           Renal                                      6.188
# 4   GRD5     Neurológico                                      6.782
# 5   GRD6  Traumatológico                                      4.881
# 6   GRD7       Esofágico                                      2.629
# 7   GRD8   Oftalmológico                                      6.720
# 8   GRD9    Circulatorio                                      5.524
# 9  GRD10      Intestinal                                      7.916

# %%
df2 = RC[["ID GRD", "Costo resolución en Clínica Privada [MM$]"]].groupby("ID GRD").mean()

# %%
df2_ordenado = df2['Costo resolución en Clínica Privada [MM$]'].sort_values()
df2_ordenado.tail(3).mean()
# Out:
# 7.538333333333334
